# %% [markdown]
# **Class Example 1**

# %%
# Import needed packages 
import numpy as np
from matplotlib import pyplot as plt

# %%
x=np.array([1,2,3])

# %%
t=np.arange(0,115,.01)

# %%
plt.plot(t, np.sin(2*np.pi*t))
